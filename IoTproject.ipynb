# %%
import numpy as np
import pandas as pd
import PIL
import math

# %%
data = pd.read_csv('./Acceleration with g 2021-04-24 16-06-41/Raw Data.csv')

# %%
data
# Out:
#         Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0       0.047140               -0.082260               -0.157288
# 1       0.051169               -0.089432               -0.166870
# 2       0.055166               -0.091827               -0.174042
# 3       0.059195               -0.091827               -0.169266
# 4       0.063223               -0.089432               -0.176437
# ...          ...                     ...                     ...
# 14931  59.996914               -0.084656               -0.164474
# 14932  60.000943               -0.087036               -0.162079
# 14933  60.004940               -0.079865               -0.159683
# 14934  60.008969               -0.082260               -0.166870
# 14935  60.012997               -0.082260               -0.166870
#
#        Acceleration z (m/s^2)  Absolute acceleration (m/s^2)
# 0                    9.573853                       9.575498
# 1                    9.578629                       9.580499
# ...

# %%
def caltheta(x, y, z):
    return math.atan(x/sqrt(z*z + y*y))

# %%
def calpsi(x, y, z):
    return math.atan(y/math.sqrt(x**2 + z**2))
    
def calphi(x, y, z):
    return math.atan(math.sqrt(x**2 + y**2)/ z)

# %%
accx = data.loc[:, "Acceleration x (m/s^2)"]

# %%
accx
# Out:
# 0       -0.082260
# 1       -0.089432
# 2       -0.091827
# 3       -0.091827
# 4       -0.089432
#            ...
# 14931   -0.084656
# 14932   -0.087036
# 14933   -0.079865
# 14934   -0.082260
# 14935   -0.082260
# Name: Acceleration x (m/s^2), Length: 14936, dtype: float64

# %%
accy = data.loc[:, "Acceleration y (m/s^2)"]
accz = data.loc[:, "Acceleration z (m/s^2)"]

# %%
def calcangle(ax, ay, az):
    return [caltheta(ax, ay, az), calpsi(ax, ay, az), calphi(ax, ay, az)]

# %%
data['theta'] = 0.0

# %%
data['psi'] = 0.0
data['phi'] = 0.0

# %%
data
# Out:
#         Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0       0.047140               -0.082260               -0.157288
# 1       0.051169               -0.089432               -0.166870
# 2       0.055166               -0.091827               -0.174042
# 3       0.059195               -0.091827               -0.169266
# 4       0.063223               -0.089432               -0.176437
# ...          ...                     ...                     ...
# 14931  59.996914               -0.084656               -0.164474
# 14932  60.000943               -0.087036               -0.162079
# 14933  60.004940               -0.079865               -0.159683
# 14934  60.008969               -0.082260               -0.166870
# 14935  60.012997               -0.082260               -0.166870
#
#        Acceleration z (m/s^2)  Absolute acceleration (m/s^2)  theta  psi  phi
# 0                    9.573853                       9.575498    0.0  0.0  0.0
# ...

# %%
data['theta'] = np.arctan(data['Acceleration x (m/s^2)']/np.sqrt(np.square(data['Acceleration y (m/s^2)'])+np.square(data['Acceleration z (m/s^2)'])))

# %%
data
# Out:
#         Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0       0.047140               -0.082260               -0.157288
# 1       0.051169               -0.089432               -0.166870
# 2       0.055166               -0.091827               -0.174042
# 3       0.059195               -0.091827               -0.169266
# 4       0.063223               -0.089432               -0.176437
# ...          ...                     ...                     ...
# 14931  59.996914               -0.084656               -0.164474
# 14932  60.000943               -0.087036               -0.162079
# 14933  60.004940               -0.079865               -0.159683
# 14934  60.008969               -0.082260               -0.166870
# 14935  60.012997               -0.082260               -0.166870
#
#        Acceleration z (m/s^2)  Absolute acceleration (m/s^2)     theta  psi  \
# 0                    9.573853                       9.575498 -0.008591  0.0
# ...

# %%
data['theta'] = (180/math.pi)*data['theta']

# %%
data
# Out:
#         Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0       0.047140               -0.082260               -0.157288
# 1       0.051169               -0.089432               -0.166870
# 2       0.055166               -0.091827               -0.174042
# 3       0.059195               -0.091827               -0.169266
# 4       0.063223               -0.089432               -0.176437
# ...          ...                     ...                     ...
# 14931  59.996914               -0.084656               -0.164474
# 14932  60.000943               -0.087036               -0.162079
# 14933  60.004940               -0.079865               -0.159683
# 14934  60.008969               -0.082260               -0.166870
# 14935  60.012997               -0.082260               -0.166870
#
#        Acceleration z (m/s^2)  Absolute acceleration (m/s^2)     theta  psi  \
# 0                    9.573853                       9.575498 -0.492216  0.0
# ...

# %%
data['psi'] = np.arctan(data['Acceleration y (m/s^2)']/np.sqrt(np.square(data['Acceleration x (m/s^2)'])+np.square(data['Acceleration z (m/s^2)'])))

data['psi'] = (180/math.pi)*data['psi']

# %%
data
# Out:
#         Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0       0.047140               -0.082260               -0.157288
# 1       0.051169               -0.089432               -0.166870
# 2       0.055166               -0.091827               -0.174042
# 3       0.059195               -0.091827               -0.169266
# 4       0.063223               -0.089432               -0.176437
# ...          ...                     ...                     ...
# 14931  59.996914               -0.084656               -0.164474
# 14932  60.000943               -0.087036               -0.162079
# 14933  60.004940               -0.079865               -0.159683
# 14934  60.008969               -0.082260               -0.166870
# 14935  60.012997               -0.082260               -0.166870
#
#        Acceleration z (m/s^2)  Absolute acceleration (m/s^2)     theta  \
# 0                    9.573853                       9.575498 -0.492216
# ...

# %%
data['phi'] = np.arctan(np.sqrt(np.square(data['Acceleration x (m/s^2)'])+np.square(data['Acceleration y (m/s^2)']))/data['Acceleration z (m/s^2)'])

data['phi'] = (180/math.pi)*data['phi']

# %%
data
# Out:
#         Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0       0.047140               -0.082260               -0.157288
# 1       0.051169               -0.089432               -0.166870
# 2       0.055166               -0.091827               -0.174042
# 3       0.059195               -0.091827               -0.169266
# 4       0.063223               -0.089432               -0.176437
# ...          ...                     ...                     ...
# 14931  59.996914               -0.084656               -0.164474
# 14932  60.000943               -0.087036               -0.162079
# 14933  60.004940               -0.079865               -0.159683
# 14934  60.008969               -0.082260               -0.166870
# 14935  60.012997               -0.082260               -0.166870
#
#        Acceleration z (m/s^2)  Absolute acceleration (m/s^2)     theta  \
# 0                    9.573853                       9.575498 -0.492216
# ...

# %%
def calculation(data):
    data['theta'] = 0.0
    data['psi'] = 0.0
    data['phi'] = 0.0
    data['theta'] = np.arctan(data['Acceleration x (m/s^2)']/np.sqrt(np.square(data['Acceleration y (m/s^2)'])+np.square(data['Acceleration z (m/s^2)'])))
    data['theta'] = (180/math.pi)*data['theta']
    data['psi'] = np.arctan(data['Acceleration y (m/s^2)']/np.sqrt(np.square(data['Acceleration x (m/s^2)'])+np.square(data['Acceleration z (m/s^2)'])))
    data['psi'] = (180/math.pi)*data['psi']
    data['phi'] = np.arctan(np.sqrt(np.square(data['Acceleration x (m/s^2)'])+np.square(data['Acceleration y (m/s^2)']))/data['Acceleration z (m/s^2)'])
    data['phi'] = (180/math.pi)*data['phi']

# %%
new_data = pd.read_csv('./Acceleration with g 2021-04-24 17-21-40/Raw Data.csv')

# %%
new_data
# Out:
#        Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0      0.058339                0.015915                9.718796
# 1      0.062367                0.015915                9.721191
# 2      0.066365                0.018295                9.714005
# 3      0.070393                0.025482                9.714005
# 4      0.074421                0.027878                9.718796
# ...         ...                     ...                     ...
# 2475   9.994142                0.027878                9.718796
# 2476   9.998171                0.030273                9.723587
# 2477  10.002169                0.025482                9.721191
# 2478  10.006197                0.020691                9.716400
# 2479  10.010225                0.018295                9.714005
#
#       Acceleration z (m/s^2)  Absolute acceleration (m/s^2)
# 0                  -0.139435                       9.719809
# 1                  -0.149002                       9.722346
# ...

# %%
calculation(new_data)

# %%
new_data
# Out:
#        Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0      0.058339                0.015915                9.718796
# 1      0.062367                0.015915                9.721191
# 2      0.066365                0.018295                9.714005
# 3      0.070393                0.025482                9.714005
# 4      0.074421                0.027878                9.718796
# ...         ...                     ...                     ...
# 2475   9.994142                0.027878                9.718796
# 2476   9.998171                0.030273                9.723587
# 2477  10.002169                0.025482                9.721191
# 2478  10.006197                0.020691                9.716400
# 2479  10.010225                0.018295                9.714005
#
#       Acceleration z (m/s^2)  Absolute acceleration (m/s^2)     theta  \
# 0                  -0.139435                       9.719809  0.093814
# ...

# %%
data2 = pd.read_csv('./Acceleration with g 2021-05-16 23-26-41/Raw Data.csv')

# %%
def calculation(data):
    data['theta'] = 0.0
    data['psi'] = 0.0
    data['phi'] = 0.0
    data['theta'] = np.arctan(data['Acceleration x (m/s^2)']/np.sqrt(np.square(data['Acceleration y (m/s^2)'])+np.square(data['Acceleration z (m/s^2)'])))
    data['theta'] = (180/math.pi)*data['theta']
    data['psi'] = np.arctan(data['Acceleration y (m/s^2)']/np.sqrt(np.square(data['Acceleration x (m/s^2)'])+np.square(data['Acceleration z (m/s^2)'])))
    data['psi'] = (180/math.pi)*data['psi']
    data['phi'] = np.arctan(np.sqrt(np.square(data['Acceleration x (m/s^2)'])+np.square(data['Acceleration y (m/s^2)']))/data['Acceleration z (m/s^2)'])
    data['phi'] = (180/math.pi)*data['phi']

# %%
calculation(data2)

# %%
data2
# Out:
#        Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# 0      0.024967                0.233780                4.353394
# 1      0.028996                0.068573                4.255234
# 2      0.032993               -0.060699                4.169037
# 3      0.037022               -0.134933                4.092422
# 4      0.041050               -0.161270                4.018204
# ...         ...                     ...                     ...
# 2482   9.990590               -0.020004                7.824982
# 2483   9.994618               -0.034363                7.841736
# 2484   9.998647                0.008728                7.863281
# 2485  10.002644                0.126038                7.889618
# 2486  10.006673                0.307999                7.925537
#
#       Acceleration z (m/s^2)  Absolute acceleration (m/s^2)     theta  \
# 0                   9.370346                      10.334896  1.296166
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(data2['Time (s)'], data2['psi'])
plt.plot(data2['Time (s)'], data2['phi'])
plt.plot(data2['Time (s)'], data2['theta'])
plt.ylabel('Angle')
plt.xlabel('time in seconds')
plt.legend(['psi', 'phi', 'theta'])
plt.title('Variation of psi, theta and phi with time')
plt.show()

# %%
data2['theta']
# Out:
# 0       1.296166
# 1       0.375946
# 2      -0.328966
# 3      -0.724979
# 4      -0.860508
#           ...
# 2482   -0.123781
# 2483   -0.215565
# 2484    0.055355
# 2485    0.802432
# 2486    1.948466
# Name: theta, Length: 2487, dtype: float64

# %%
new_data = pd.read_csv('./Acceleration with g 2021-04-24 17-21-40/Raw Data.csv')

# %%
import matplotlib.pyplot as plt
plt.plot(new_data['Time (s)'], new_data['psi'])
plt.plot(new_data['Time (s)'], new_data['phi'])
plt.plot(new_data['Time (s)'], new_data['theta'])
plt.ylabel('Angle')
plt.xlabel('time in seconds')
plt.legend(['psi', 'phi', 'theta'])
plt.title('Variation of psi, theta and phi with time')
plt.show()
